# %%
import pandas as pd

import datetime

import numpy as np

import matplotlib.pyplot as plt

import yfinance as yf

# %matplotlib inline

# %%
start = "2021-01-01"
end = '2022-10-08'
amzn = yf.download('AMZN',start,end)
aapl = yf.download('aapl',start,end)
msft = yf.download('Msft',start,end)
google = yf.download('GOOG',start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
amzn.duplicated()
# Out:
# Date
# 2021-01-04 00:00:00-05:00    False
# 2021-01-05 00:00:00-05:00    False
# 2021-01-06 00:00:00-05:00    False
# 2021-01-07 00:00:00-05:00    False
# 2021-01-08 00:00:00-05:00    False
#                              ...
# 2022-10-03 00:00:00-04:00    False
# 2022-10-04 00:00:00-04:00    False
# 2022-10-05 00:00:00-04:00    False
# 2022-10-06 00:00:00-04:00    False
# 2022-10-07 00:00:00-04:00    False
# Length: 445, dtype: bool

# %%
aapl.duplicated()
# Out:
# Date
# 2021-01-04 00:00:00-05:00    False
# 2021-01-05 00:00:00-05:00    False
# 2021-01-06 00:00:00-05:00    False
# 2021-01-07 00:00:00-05:00    False
# 2021-01-08 00:00:00-05:00    False
#                              ...
# 2022-10-03 00:00:00-04:00    False
# 2022-10-04 00:00:00-04:00    False
# 2022-10-05 00:00:00-04:00    False
# 2022-10-06 00:00:00-04:00    False
# 2022-10-07 00:00:00-04:00    False
# Length: 445, dtype: bool

# %%
msft.duplicated()
# Out:
# Date
# 2021-01-04 00:00:00-05:00    False
# 2021-01-05 00:00:00-05:00    False
# 2021-01-06 00:00:00-05:00    False
# 2021-01-07 00:00:00-05:00    False
# 2021-01-08 00:00:00-05:00    False
#                              ...
# 2022-10-03 00:00:00-04:00    False
# 2022-10-04 00:00:00-04:00    False
# 2022-10-05 00:00:00-04:00    False
# 2022-10-06 00:00:00-04:00    False
# 2022-10-07 00:00:00-04:00    False
# Length: 445, dtype: bool

# %%
google.duplicated()
# Out:
# Date
# 2021-01-04 00:00:00-05:00    False
# 2021-01-05 00:00:00-05:00    False
# 2021-01-06 00:00:00-05:00    False
# 2021-01-07 00:00:00-05:00    False
# 2021-01-08 00:00:00-05:00    False
#                              ...
# 2022-10-03 00:00:00-04:00    False
# 2022-10-04 00:00:00-04:00    False
# 2022-10-05 00:00:00-04:00    False
# 2022-10-06 00:00:00-04:00    False
# 2022-10-07 00:00:00-04:00    False
# Length: 445, dtype: bool

# %%
print(amzn.isnull())
# Out:
#                             Open   High    Low  Close  Adj Close  Volume
# Date
# 2021-01-04 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-05 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-06 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-07 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-08 00:00:00-05:00  False  False  False  False      False   False
# ...                          ...    ...    ...    ...        ...     ...
# 2022-10-03 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-04 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-05 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-06 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-07 00:00:00-04:00  False  False  False  False      False   False
#
# [445 rows x 6 columns]

# %%
print(aapl.isnull())
# Out:
#                             Open   High    Low  Close  Adj Close  Volume
# Date
# 2021-01-04 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-05 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-06 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-07 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-08 00:00:00-05:00  False  False  False  False      False   False
# ...                          ...    ...    ...    ...        ...     ...
# 2022-10-03 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-04 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-05 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-06 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-07 00:00:00-04:00  False  False  False  False      False   False
#
# [445 rows x 6 columns]

# %%
print(msft.isnull())
# Out:
#                             Open   High    Low  Close  Adj Close  Volume
# Date
# 2021-01-04 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-05 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-06 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-07 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-08 00:00:00-05:00  False  False  False  False      False   False
# ...                          ...    ...    ...    ...        ...     ...
# 2022-10-03 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-04 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-05 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-06 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-07 00:00:00-04:00  False  False  False  False      False   False
#
# [445 rows x 6 columns]

# %%
print(google.isnull())
# Out:
#                             Open   High    Low  Close  Adj Close  Volume
# Date
# 2021-01-04 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-05 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-06 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-07 00:00:00-05:00  False  False  False  False      False   False
# 2021-01-08 00:00:00-05:00  False  False  False  False      False   False
# ...                          ...    ...    ...    ...        ...     ...
# 2022-10-03 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-04 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-05 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-06 00:00:00-04:00  False  False  False  False      False   False
# 2022-10-07 00:00:00-04:00  False  False  False  False      False   False
#
# [445 rows x 6 columns]

# %% [markdown]
# What was the change in stock price over time

# %%
# amazon=pd.DataFrame(amzn)
# amazon= amazon.assign(diff_Open_Close =amazon['Open']-amazon['Close'])
# amazon.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-03 00:00:00-04:00  113.580002  116.910004  112.449997  115.879997
# 2022-10-04 00:00:00-04:00  119.889999  123.000000  119.790001  121.089996
# 2022-10-05 00:00:00-04:00  118.580002  121.750000  117.690002  120.949997
# 2022-10-06 00:00:00-04:00  120.769997  121.529999  119.500000  120.300003
# 2022-10-07 00:00:00-04:00  118.000000  118.169998  113.879997  114.559998
#
#                             Adj Close    Volume  diff_Open_Close
# Date
# 2022-10-03 00:00:00-04:00  115.879997  50941900        -2.299995
# 2022-10-04 00:00:00-04:00  121.089996  62812600        -1.199997
# 2022-10-05 00:00:00-04:00  120.949997  48217500        -2.369995
# 2022-10-06 00:00:00-04:00  120.300003  42253800         0.469994
# 2022-10-07 00:00:00-04:00  114.559998  54626400         3.440002

# %%
# google=pd.DataFrame(google)
# google= google.assign(diff_Open_Close =google['Open']-google['Close'])
# google.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-03 00:00:00-04:00   97.220001   99.970001   97.019997   99.300003
# 2022-10-04 00:00:00-04:00  101.040001  102.720001  101.040001  102.410004
# 2022-10-05 00:00:00-04:00  100.690002  102.739998   99.739998  102.220001
# 2022-10-06 00:00:00-04:00  101.500000  103.730003  101.500000  102.239998
# 2022-10-07 00:00:00-04:00  100.650002  101.419998   99.209999   99.570000
#
#                             Adj Close    Volume  diff_Open_Close
# Date
# 2022-10-03 00:00:00-04:00   99.300003  24840000        -2.080002
# 2022-10-04 00:00:00-04:00  102.410004  22580900        -1.370003
# 2022-10-05 00:00:00-04:00  102.220001  18475500        -1.529999
# 2022-10-06 00:00:00-04:00  102.239998  17156200        -0.739998
# 2022-10-07 00:00:00-04:00   99.570000  24232300         1.080002

# %%
# microsoft=pd.DataFrame(msft)
# microsoft= microsoft.assign(diff_Open_Close =microsoft['Open']-microsoft['Close'])
# microsoft.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-03 00:00:00-04:00  235.410004  241.610001  234.660004  240.740005
# 2022-10-04 00:00:00-04:00  245.089996  250.360001  244.979996  248.880005
# 2022-10-05 00:00:00-04:00  245.990005  250.580002  244.100006  249.199997
# 2022-10-06 00:00:00-04:00  247.929993  250.339996  246.080002  246.789993
# 2022-10-07 00:00:00-04:00  240.899994  241.320007  233.169998  234.240005
#
#                             Adj Close    Volume  diff_Open_Close
# Date
# 2022-10-03 00:00:00-04:00  240.740005  28880400        -5.330002
# 2022-10-04 00:00:00-04:00  248.880005  34888400        -3.790009
# 2022-10-05 00:00:00-04:00  249.199997  20347100        -3.209991
# 2022-10-06 00:00:00-04:00  246.789993  20239900         1.139999
# 2022-10-07 00:00:00-04:00  234.240005  37732400         6.659988

# %%
# apple=pd.DataFrame(aapl)
# apple= apple.assign(diff_Open_Close =apple['Open']-apple['Close'])
# apple.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-03 00:00:00-04:00  138.210007  143.070007  137.690002  142.449997
# 2022-10-04 00:00:00-04:00  145.029999  146.220001  144.259995  146.100006
# 2022-10-05 00:00:00-04:00  144.070007  147.380005  143.009995  146.399994
# 2022-10-06 00:00:00-04:00  145.809998  147.539993  145.220001  145.429993
# 2022-10-07 00:00:00-04:00  142.539993  143.100006  139.449997  140.089996
#
#                             Adj Close     Volume  diff_Open_Close
# Date
# 2022-10-03 00:00:00-04:00  142.449997  114311700        -4.239990
# 2022-10-04 00:00:00-04:00  146.100006   87830100        -1.070007
# 2022-10-05 00:00:00-04:00  146.399994   79471000        -2.329987
# 2022-10-06 00:00:00-04:00  145.429993   68402200         0.380005
# 2022-10-07 00:00:00-04:00  140.089996   85859100         2.449997

# %%
# amazon['diff_Open_Close'].plot(label = 'AMZN', figsize = (15,7))
# google['diff_Open_Close'].plot(label = 'GOOG')
# microsoft['diff_Open_Close'].plot(label = 'MSFT')
# apple['diff_Open_Close'].plot(label = 'AAPL')
# plt.title("Stock's Price of AMAZON,APPLE,MICROSOFT and GOOGLE")
# plt.legend()

# %%
amzn['Adj Close'].plot(label = 'AMZN', figsize = (15,7))
google['Adj Close'].plot(label = 'GOOG')
msft['Adj Close'].plot(label = 'MSFT')
aapl['Adj Close'].plot(label = 'AAPL')
plt.title("Stock's Price of AMAZON,APPLE,MICROSOFT and GOOGLE")
plt.legend()

# %% [markdown]
# Visualize the Change in a stock's Volume being traded,overtime?

# %%
amzn['Volume'].plot(label = 'AMZN', figsize = (15,7))
google['Volume'].plot(label = 'GOOG')
msft['Volume'].plot(label = 'MSFT')
aapl['Volume'].plot(label = 'AAPL')
plt.title("STOCK'S VOLUME OF AMAZON,APPLE,MICROSOFT and GOOGLE")
plt.legend()

# %%
plt.figure(figsize = (18,9))
plt.plot(range(amazon.shape[0]),(amazon['Low']+amazon['High'])/2.0)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %% [markdown]
# ['MAVG']  = ['adj close'].rolling(20).mean

# %%
amzn['MAVG']  = amzn['Adj Close'].rolling(20).mean
amzn
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  163.500000  163.600006  157.201004  159.331497
# 2021-01-05 00:00:00-05:00  158.300507  161.169006  158.253006  160.925507
# 2021-01-06 00:00:00-05:00  157.324005  159.875504  156.557999  156.919006
# 2021-01-07 00:00:00-05:00  157.850006  160.427002  157.750000  158.108002
# 2021-01-08 00:00:00-05:00  159.000000  159.531998  157.110001  159.134995
# ...                               ...         ...         ...         ...
# 2022-10-03 00:00:00-04:00  113.580002  116.910004  112.449997  115.879997
# 2022-10-04 00:00:00-04:00  119.889999  123.000000  119.790001  121.089996
# 2022-10-05 00:00:00-04:00  118.580002  121.750000  117.690002  120.949997
# 2022-10-06 00:00:00-04:00  120.769997  121.529999  119.500000  120.300003
# 2022-10-07 00:00:00-04:00  118.000000  118.169998  113.879997  114.559998
#
#                             Adj Close    Volume  \
# Date
# ...

# %%
# Out:
#                                  Open        High        Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-05 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-06 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-07 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-08 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-11 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-12 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-13 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-14 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-15 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-19 00:00:00-05:00         NaN         NaN        NaN         NaN
# 2021-01-20 00:00:00-05:00         NaN         NaN        NaN         NaN
# ...

# %%
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-03 00:00:00-04:00  120.952775  123.254380  118.915865  121.137795
# 2022-10-04 00:00:00-04:00  121.070640  123.382821  119.069480  121.294975
# 2022-10-05 00:00:00-04:00  121.228940  123.492515  119.222325  121.435170
# 2022-10-06 00:00:00-04:00  121.345950  123.575975  119.339325  121.507620
# 2022-10-07 00:00:00-04:00  121.394950  123.617750  119.374585  121.545115
#
#                             Adj Close      Volume  diff_Open_Close
# Date
# 2022-10-03 00:00:00-04:00  121.137795  69547083.0        -0.185020
# 2022-10-04 00:00:00-04:00  121.294975  69078169.0        -0.224335
# 2022-10-05 00:00:00-04:00  121.435170  68240084.0        -0.206230
# 2022-10-06 00:00:00-04:00  121.507620  67725782.0        -0.161670
# 2022-10-07 00:00:00-04:00  121.545115  67526386.0        -0.150165

# %%
amazon1['MAVG']=amazon1['Adj Close'].rolling(20).mean
amazon1
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00   87.876999   88.032501   85.392502   86.412003
# 2021-01-05 00:00:00-05:00   86.250000   87.383499   85.900749   87.045998
# 2021-01-06 00:00:00-05:00   85.131500   87.400002   84.949997   86.764503
# 2021-01-07 00:00:00-05:00   87.002998   89.419998   86.852501   89.362503
# 2021-01-08 00:00:00-05:00   89.399002   90.491997   88.676750   90.360497
# ...                               ...         ...         ...         ...
# 2022-10-03 00:00:00-04:00   97.220001   99.970001   97.019997   99.300003
# 2022-10-04 00:00:00-04:00  101.040001  102.720001  101.040001  102.410004
# 2022-10-05 00:00:00-04:00  100.690002  102.739998   99.739998  102.220001
# 2022-10-06 00:00:00-04:00  101.500000  103.730003  101.500000  102.239998
# 2022-10-07 00:00:00-04:00  100.650002  101.419998   99.209999   99.570000
#
#                             Adj Close    Volume  diff_Open_Close  \
# ...

# %%
moving_average= 20

for moving_average in moving_average:
    coulmn_name = moving_average

# %%
amazon['Daily Return'] = amazon['Adj Close'].pct_change()
apple['Daily Return'] = apple['Adj Close'].pct_change()
google['Daily Return'] = google['Adj Close'].pct_change()
microsoft['Daily Return'] = microsoft['Adj Close'].pct_change()
print(amazon,apple,google,microsoft)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  163.500000  163.600006  157.201004  159.331497
# 2021-01-05 00:00:00-05:00  158.300507  161.169006  158.253006  160.925507
# 2021-01-06 00:00:00-05:00  157.324005  159.875504  156.557999  156.919006
# 2021-01-07 00:00:00-05:00  157.850006  160.427002  157.750000  158.108002
# 2021-01-08 00:00:00-05:00  159.000000  159.531998  157.110001  159.134995
# ...                               ...         ...         ...         ...
# 2022-10-03 00:00:00-04:00  113.580002  116.910004  112.449997  115.879997
# 2022-10-04 00:00:00-04:00  119.889999  123.000000  119.790001  121.089996
# 2022-10-05 00:00:00-04:00  118.580002  121.750000  117.690002  120.949997
# 2022-10-06 00:00:00-04:00  120.769997  121.529999  119.500000  120.300003
# 2022-10-07 00:00:00-04:00  118.000000  118.169998  113.879997  114.559998
#
#                             Adj Close    Volume  diff_Open_Close  \
# ...
